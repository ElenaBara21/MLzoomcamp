# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("data-car.csv")

# %%
data.shape
# Out:
# (11914, 16)

# %%
data.head()
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
# 3               6.0            MANUAL  rear wheel drive              2.0
# 4               6.0            MANUAL  rear wheel drive              2.0
#
#                          Market Category Vehicle Size Vehicle Style  \
# ...

# %%
data['Make'].value_counts()
# Out:
# Chevrolet        1123
# Ford              881
# Volkswagen        809
# Toyota            746
# Dodge             626
# Nissan            558
# GMC               515
# Honda             449
# Mazda             423
# Cadillac          397
# Mercedes-Benz     353
# Suzuki            351
# BMW               334
# Infiniti          330
# Audi              328
# Hyundai           303
# Volvo             281
# Subaru            256
# Acura             252
# Kia               231
# Mitsubishi        213
# Lexus             202
# Buick             196
# Chrysler          187
# Pontiac           186
# Lincoln           164
# Oldsmobile        150
# Land Rover        143
# Porsche           136
# Saab              111
# Aston Martin       93
# Plymouth           82
# Bentley            74
# Ferrari            69
# FIAT               62
# Scion              60
# Maserati           58
# Lamborghini        52
# Rolls-Royce        31
# Lotus              29
# Tesla              18
# ...

# %%
# np.__version__

# %%
au = data[
    data['Make'] == 'Audi'
]
# Out:
#        Make Model  Year             Engine Fuel Type  Engine HP  \
# 17     Audi   100  1992             regular unleaded      172.0
# 18     Audi   100  1992             regular unleaded      172.0
# 19     Audi   100  1992             regular unleaded      172.0
# 20     Audi   100  1992             regular unleaded      172.0
# 21     Audi   100  1992             regular unleaded      172.0
# ...     ...   ...   ...                          ...        ...
# 10901  Audi   TTS  2016  premium unleaded (required)      292.0
# 10902  Audi   TTS  2017  premium unleaded (required)      292.0
# 11178  Audi    V8  1992             regular unleaded      276.0
# 11179  Audi    V8  1993             regular unleaded      276.0
# 11180  Audi    V8  1994             regular unleaded      276.0
#
#        Engine Cylinders Transmission Type      Driven_Wheels  Number of Doors  \
# 17                  6.0            MANUAL  front wheel drive              4.0
# ...

# %%
aud = data.groupby(['Audi'])['Model'].value_counts()
aud
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [68], in <cell line: 1>()
# ----> 1 aud = data.groupby(['Audi'])['Model'].value_counts()
#       2 aud
#
# File ~\env\lib\site-packages\pandas\core\frame.py:7718, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    7713 axis = self._get_axis_number(axis)
#    7715 # https://github.com/python/mypy/issues/7642
#    7716 # error: Argument "squeeze" to "DataFrameGroupBy" has incompatible type
#    7717 # "Union[bool, NoDefault]"; expected "bool"
# -> 7718 return DataFrameGroupBy(
#    7719     obj=self,
#    7720     keys=by,
#    7721     axis=axis,
#    7722     level=level,
#    7723     as_index=as_index,
#    7724     sort=sort,
#    7725     group_keys=group_keys,
#    7726     squeeze=squeeze,  # type: ignore[arg-type]
#    7727     observed=observed,
# ...

# %%
data.isnull().sum()
# Out:
# Make                    0
# Model                   0
# Year                    0
# Engine Fuel Type        3
# Engine HP              69
# Engine Cylinders       30
# Transmission Type       0
# Driven_Wheels           0
# Number of Doors         6
# Market Category      3742
# Vehicle Size            0
# Vehicle Style           0
# highway MPG             0
# city mpg                0
# Popularity              0
# MSRP                    0
# dtype: int64

# %%
data["Engine Cylinders"].median()
# Out:
# 6.0

# %%
data['Engine Cylinders'] = data['Engine Cylinders'].fillna(value= data['Engine Cylinders'].median())

# %%
data["Engine Cylinders"].median()
# Out:
# 6.0

# %%
data.groupby('Lotus',"Engine HP", "Engine Cylinders")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\env\lib\site-packages\pandas\core\generic.py:550, in NDFrame._get_axis_number(cls, axis)
#     549 try:
# --> 550     return cls._AXIS_TO_AXIS_NUMBER[axis]
#     551 except KeyError:
#
# KeyError: 'Engine HP'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Input In [56], in <cell line: 1>()
# ----> 1 data.groupby('Lotus',"Engine HP", "Engine Cylinders")
#
# File ~\env\lib\site-packages\pandas\core\frame.py:7713, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    7711 if level is None and by is None:
#    7712     raise TypeError("You have to supply one of 'by' and 'level'")
# -> 7713 axis = self._get_axis_number(axis)
# ...

# %%
mis_imp = [
    "main_camera_mp",
    "selfie_camera_mp",
    "int_memory",
    "ram",
    "battery",
    "weight",
]
